# %%
from IPython.display import HTML
HTML(f"""
<style>
.guide-title {{
    background: #1a1a1a;
    padding: 12px 16px;
    border-left: 4px solid #00ff9d;
    font-size: 16px;
    font-weight: 600;
    color: #e6e6e6;
    margin-bottom: 10px;
    border-radius: 6px;
}}
.code-box-container {{
    position: relative;
    background: #111;
    padding: 16px 20px;
    border-radius: 10px;
    border: 1px solid #333;
    font-family: monospace;
    color: #00ff9d;
    margin-top: 5px;
}}
.copy-btn {{
    position: absolute; 
    top: 8px; 
    right: 10px;
    background: #00ff9d; 
    color: #000;
    border: none; 
    padding: 6px 12px;
    border-radius: 6px; 
    cursor: pointer; 
    font-weight: bold;
    transition: 0.25s;
}}
.copy-btn:hover {{
    background: #00d786;
}}
img {{
    margin-top: 14px;
    border-radius: 8px;
    border: 1px solid #333;
}}
</style>
<div class="guide-title">
    👉 Anh chị vui lòng thực hiện <b>4 bước hướng dẫn</b> bên dưới để tải model cần thiết:
</div>
<div class="code-box-container">
    <button class="copy-btn" onclick="copyCommand()">COPY</button>
    <div id="commandText">
source env.txt && chmod +x wan22.sh && bash wan22.sh
    </div>
</div>
<div>
    <img src="{html_img}" style="max-width:100%;">
</div>
<script>
function copyCommand(){{
    navigator.clipboard.writeText(
        document.getElementById("commandText").innerText
    );
    const btn = document.querySelector(".copy-btn");
    btn.innerText = "COPIED ✔";
    setTimeout(() => btn.innerText = "COPY", 1500);
}}
</script>
""")
